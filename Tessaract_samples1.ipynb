# %% [markdown]
# <a href="https://colab.research.google.com/github/ajitkumarkp/ML/blob/master/Tessaract_samples1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Download Tessaract library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd drive/My\ Drive/
# Out:
# /content/drive/My Drive

# %%
# !pwd
# Out:
# /content/drive/My Drive/Tessaract

# %%
# !apt install libtesseract-dev tesseract-ocr > /dev/null
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %% [markdown]
# ## Download Tessaract library Python version

# %%
# !pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.4-py2.py3-none-any.whl size=13431 sha256=b04f38fdc943d3a510b9066ad0728a6ee06030ed2a479c5daa1dbe55d6a77b59
#   Stored in directory: /root/.cache/pip/wheels/63/2a/a0/7596d2e0a73cf0aeffd6f6170862c4e73f3763b7827e48691a
# Successfully built pytesseract
# ...

# %%
import pytesseract
import cv2
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %% [markdown]
# ## Sample-1

# %%
# !wget https://www.dropbox.com/s/v3z5l2mq8swea1e/keras-snapshot.jpg?dl=1 -O text1.jpg --quiet

# %%
img = cv2.imread("text1.jpg");plt.imshow(img[...,::-1], cmap='gray')

# %%
text1 = pytesseract.image_to_string('text1.jpg')
print(text1)
# Out:
# Keras is a high-level neural networks API, written in Python and capable of running on top of
# TensorFlow, CNTK, or Theano. It was developed with a focus on enabling fast experimentation.
# Being able to go from idea to result with the least possible delay is key to doing good research.

# %% [markdown]
# ## Sample-2

# %%
# !wget https://www.dropbox.com/s/ai7dsbpsyjb2inx/cnn-snapshot.jpg?dl=1 -O text2.jpg --quiet

# %%
img = cv2.imread("text2.jpg");plt.imshow(img[...,::-1], cmap='gray')

# %%
text2 = pytesseract.image_to_string('text2.jpg')
print(text2)
# Out:
# Chapter 9
#
# Convolutional Networks
#
# Convolutional networks (LeCun, 1989), also known as convolutional neural
# networks, or CNNs, are a specialized kind of neural network for processing data
# that has a known grid-like topology. Examples include time-series data, which can
# be thought of as a 1-D grid taking samples at regular time intervals, and image data,
# which can be thought of as a 2-D grid of pixels. Convolutional networks have been
# tremendously successful in practical applications. The name “convolutional neural
# network” indicates that the network employs a mathematical operation called
# convolution. Convolution is a specialized kind of linear operation. Convolutional
# networks are simply neural networks that use convolution in place of general matrix
# multiplication in at least one of their layers.
#
# In this chapter, we first describe what convolution is. Next, we explain the
# motivation behind using convolution in a neural network. We then describe an
# ...

# %% [markdown]
# ## Sample-3

# %%
# !wget https://www.dropbox.com/s/zrr4tvozzjbfrzv/forsyth_scan.jpg?dl=1 -O text3.jpg --quiet

# %%
img = cv2.imread("text3.jpg");plt.imshow(img[...,::-1], cmap='gray')

# %%
text3 = pytesseract.image_to_string('text3.jpg')
print(text3)
# Out:
# Computer Vision
#
# A MODERN APPROACH
#
# DAVID A. FORSYTH
#
# University of California at Berkeley
#
# JEAN PONCE
#
# University of Illinois at Urbana-Champaign
#
#
#
# Whether in the entertainment industry (building three-dimensiona! computer models), medical imaging,
# interpreting satellite images (both for military and civilian purposes), the applications of computer
# vision is varied and wide ranging. And this compact yet comprehensive text provides a survey of the
# field of computer vision and views it from a modern perspective. It is self-contained, accessible, and
# lays emphasis on basic geometry, physics of imaging and probabilistic techniques.
#
# Throughout, the authors attempt to lay bare the essentials of computer vision to the students as
# also to the professionals. The text reflects the latest developments in the field and integrates the
# learning tools that aid understanding.
#
#
#
# ...

# %% [markdown]
# ## Sample-1 with image-to-boxes

# %%
img = cv2.imread("text1.jpg");plt.imshow(img[...,::-1], cmap='gray')

# %%
boxes = pytesseract.image_to_boxes("text1.jpg")
print(boxes[:105])
# Out:
# K 12 65 14 76 0
# e 14 65 21 76 0
# r 22 65 29 73 0
# a 31 65 35 73 0
# s 36 65 42 73 0
# i 43 65 49 73 0
# s 55 65 6

# %% [markdown]
# ## Sample-1 with image-to-boxes as "dict"

# %%
boxes = pytesseract.image_to_boxes("text1.jpg",output_type="dict")
print(boxes.keys())
# Out:
# dict_keys(['char', 'left', 'bottom', 'right', 'top', 'page'])

# %% [markdown]
# ## Sample-1 with image-to-data to extract useful info

# %%
data = pytesseract.image_to_data("text1.jpg")
print(data[:500])
# Out:
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	688	91	-1
# 2	1	1	0	0	0	11	14	662	63	-1
# 3	1	1	1	0	0	11	14	662	63	-1
# 4	1	1	1	1	0	12	14	645	15	-1
# 5	1	1	1	1	1	12	15	30	11	92	Keras
# 5	1	1	1	1	2	43	15	21	11	95	is
# 5	1	1	1	1	3	69	18	7	8	95	a
# 5	1	1	1	1	4	82	14	66	15	95	high-level
# 5	1	1	1	1	5	154	15	42	11	96	neural
# 5	1	1	1	1	6	202	15	57	11	95	networks
# 5	1	1	1	1	7	260	15	34	11	95	API,
# 5	1	1	1	1	8	296	15	56	13	89	written
# 5	1	1	1	1	9	358	15	11	11	96	in
# 5	1

# %%
data = pytesseract.image_to_data("text1.jpg",output_type="dict")
print(data.keys())
# Out:
# dict_keys(['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num', 'left', 'top', 'width', 'height', 'conf', 'text'])

# %% [markdown]
# ## Sample- Image to PDF(searchable text)

# %%
image2pdf = pytesseract.image_to_pdf_or_hocr('text2.jpg')
with open('text2.pdf', 'w+b') as f:
    f.write(image2pdf)

# %% [markdown]
# ## Sample- Recognizing the text orientation in image

# %%
# !wget https://wiki.openoffice.org/w/images/c/c2/WG3Ch7F14.png -O text3.png --quiet

# %%
img = cv2.imread("text3.png");plt.imshow(img[...,::-1], cmap='gray')

# %%
osd = pytesseract.image_to_osd("text3.png")
print(osd)
# Out:
# Page number: 0
# Orientation in degrees: 270
# Rotate: 90
# Orientation confidence: 0.38
# Script: Latin
# Script confidence: 3.33

# %% [markdown]
# # For Other languages eg: German

# %%
# !apt install tesseract-ocr-deu > /dev/null
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# !wget https://www.dropbox.com/s/geevhmy62dy4pzh/german.jpg?dl=0 -O german.jpg --quiet

# %%
img = cv2.imread("german.jpg");plt.imshow(img[...,::-1], cmap='gray')

# %%
text4 = pytesseract.image_to_string('german.jpg',lang='eng')
print(text4)
# Out:
# English - detected ~ rod German ~
#
# Can we check x K6nnen wir
#
# whether Uberpriifen, ob
# Tesseract Tesseract Deutsch
# understand versteht?
#
# German?

# %%
text4_german = pytesseract.image_to_string('german.jpg',lang='deu')
print(text4_german)
# Out:
# English - detected = eo German =
#
# Can we check x Können wir
#
# whether überprüfen, ob
# Tesseract Tesseract Deutsch
# understand versteht?
#
# German?

# %% [markdown]
# # Detecting Text as part of an image scene (detection works quite well)

# %%
# !wget https://www.dropbox.com/s/jat0z82d76zlkjg/book1.jpg?dl=1 -O book1.jpg --quiet

# %%
img = cv2.imread("book1.jpg");plt.imshow(img[...,::-1], cmap='gray')

# %%
text5 = pytesseract.image_to_string('book1.jpg')
print(text5)
# Out:
# Computer Vision
# A MODERN APPROACH
#
# DAVID A. FORSYTH
#
# University of California at Berkeley
#
# JEAN PONCE
#
# University of Illinois at Urbana-Champaign
#
# Whether in the entertainment industry (building three-dimensiona! computer models), medical imaging,
# interpreting satellite images (both for military and civilian purposes), the applications of computer
# vision is varied and wide ranging. And this compact yet comprehensive text provides a survey of the
# field of computer vision and views it from a modern perspective. It is self-contained, accessible, and
# lays emphasis on basic geometry, physics of imaging and probabilistic techniques.
#
# Throughout, the authors attempt to lay bare the essentials of computer vision to the students as
# also to the professionals. The text reflects the latest developments in the field and integrates the
# learning tools that aid understanding.
#
# ...

# %% [markdown]
# # Detection under oclusion/distortion (not good)

# %%
# !wget https://www.dropbox.com/s/uwrdek4jjac4ysz/book2.jpg?dl=1 -O book2.jpg --quiet

# %%
img = cv2.imread("book2.jpg");plt.imshow(img[...,::-1], cmap='gray')

# %%
text6 = pytesseract.image_to_string('book2.jpg')
print(text6)
# Out:
# The Impact of the Highly Improbable

# %% [markdown]
# ## Problems with OCR

# %% [markdown]
# The tesseract api provides several page segmentation modes if you want to run OCR on only a small region or in different orientations, etc.
#
# Here's a list of the supported page segmentation modes(psm) by tesseract -
#
# * Orientation and script detection (OSD) only.
# * Automatic page segmentation with OSD.
# * Automatic page segmentation, but no OSD, or OCR.
# * Fully automatic page segmentation, but no OSD. (Default)
# * Assume a single column of text of variable sizes.
# * Assume a single uniform block of vertically aligned text.
# * Assume a single uniform block of text.
# * Treat the image as a single text line.
# * Treat the image as a single word.
# * Treat the image as a single word in a circle.
# * Treat the image as a single character.
# * Sparse text. Find as much text as possible in no particular order.
# * Sparse text with OSD.
# * Raw line. Treat the image as a single text line, bypassing hacks that are * * * Tesseract-specific.

# %%
book2_text = pytesseract.image_to_string('book2.jpg')
print(book2_text)
# Out:
# The Impact of the Highly Improbable

# %%
img = cv2.imread("book2.jpg", 0)
plt.imshow(img, cmap="gray")

# %%
book2_text = pytesseract.image_to_string(img)
print(book2_text)
# Out:
# y
#
# hris Anderson,
# author of The Long Tail
#
# Financial Times
#
#
#
# soa
#
# The Impact of the Highly Improbable
#
# Nassim Nicholas Taleb

# %%
img_neg = 255-img
plt.imshow(img_neg, cmap="gray")

# %%
book2_text = pytesseract.image_to_string(img_neg)
print(book2_text)
# Out:
# y
#
# awe
# author of The Long Tail
#
# Financial Times
#
#
#
# Swan
#
# The Impact of the Highly Improbable
#
# Nassim Nicholas Taleb

# %% [markdown]
# #Eg2: Driving License

# %%
# !wget https://www.dropbox.com/s/rdaha84n8jo3bmw/dl.jpg?dl=0 -O dl.jpg --quiet

# %%
img = cv2.imread("dl.jpg")
plt.imshow(img, cmap="gray")

# %%
dl2_text = pytesseract.image_to_string(img)
print(dl2_text)
# Out:
# DRIVER LICENSE
#
# heer toate .
#
# 123 486 789 Serie Stas,
# tate
#
# MURPHY,
#
# BRENNA ANNA C
# bomsun scm LO wl
# OUT LeTe one F
# ooraaiin NONE” ms |
# 08/20/2020 BCELZ BRO q
#
#
#
# IVANYWHERE STREET
# ITY, DL
#
# 00 asosse7eo 67890-1071 ae NA uare

# %% [markdown]
# Small font is not detecte above, resize x2 and try:

# %%
img_resized = cv2.resize(img, None, fx=2, fy=2, interpolation= cv2.INTER_CUBIC)
plt.imshow(img_resized, cmap="gray")

# %%
dl2_text = pytesseract.image_to_string(img_resized)
print(dl2_text)
# Out:
# New York DRIVER LICENSE
# ONSTTMAS TIES,
#
# NY USA
#
# 123 456 789 eerie,
#
# >
# m
#
#
#
# 1,2 Name
# MURPHY,
# BRENNA ANNA C
#
# Eo
# ov/ou/i970 cH
#
# oerzorzdi2 NONE st ZA
# 08/20/2020 BCELZ
#
# a pm
#
#
#
# iii at ANYWHERE STREET
# "ten NA
#
# 7
# 50D ASD456789 §1896-101 VY ccpin Dover 4 tay

# %% [markdown]
# Dates are not detected. Convert resized image to GS and try:

# %%
img_resized_gs = cv2.cvtColor(img_resized, cv2.COLOR_BGR2GRAY)
plt.imshow(img_resized_gs, cmap="gray")

# %%
dl2_text = pytesseract.image_to_string(img_resized_gs)
print(dl2_text)
# Out:
# NY USA
#
# New York DRIVER LICENSE
#
# TA
#
# 4d Customer identifier ny q
#
# 123 456 789 Senarsisaete,
# 1,2 Name
#
# MURPHY,
#
# BRENNA ANNA C
#
# 3 Date of birth 9 Class 15 Sex
# 01/01/1970 CM F a
# 4a Date of issue Qa Endorsements 16 Height ll
# 08/20/2012 NONE 54"
# 4b Date of expiry 12 Restrictions 18 Eyes |
# 08/20/2020 BCELZ BRO
#
#
#
# Ptr
#
# 8 Address
#
# 111 ANYWHERE STREET
# G  CITY,DL
#
# 5 DD AS0456789 67890-101
#
#
#
# P organ Donor A Nuare

# %% [markdown]
# Almost everthing relevant is detected!

# %% [markdown]
# ## Eg3: License plate detection

# %%
# !wget "https://www.dropbox.com/s/xz24vxrp4uvvnri/license_plate.jpg?dl=0" -O lp1.jpg --quiet

# %%
img = cv2.imread("lp1.jpg")
plt.imshow(img[...,::-1], cmap="gray")

# %%
dl2_text = pytesseract.image_to_string(img)
print(dl2_text)
# Out:
# Tiley)

# %% [markdown]
# Convert to GS:

# %%
img_gs = cv2.imread("lp1.jpg", 0)
plt.imshow(img_gs, cmap="gray")
dl2_text = pytesseract.image_to_string(img_gs)
print(dl2_text)
# Out:
# Tilley

# %% [markdown]
# Convert to GS and negative:

# %%
img_neg = 255-img_gs
plt.imshow(img_neg, cmap="gray")

dl2_text = pytesseract.image_to_string(img_neg)
print(dl2_text)
# Out:
# T]reviver auto

# %% [markdown]
# Try binary thresholding:

# %%
th, img_thresh = cv2.threshold(img_neg, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
plt.imshow(img_thresh, cmap="gray")

# %%
dl2_text = pytesseract.image_to_string(img_thresh)
print(dl2_text)
# Out:
# Fy reviver auto

# %% [markdown]
# The text is almost centered and we can ask Tesseract to not look for Text all over the image, but only look for text which can make up a single block. This might give us a better result.

# %%
config = ('--psm 6')
lp_text_psm6 = pytesseract.image_to_string('lp1.jpg', config=config)
print(lp_text_psm6)
# Out:
# 6xSU832

# %% [markdown]
# ## eg4: Street signs

# %%
# !wget https://www.dropbox.com/s/uwlnxiihqgni57o/streetsign1.jpg?dl=0 -O streetsign1.jpg --quiet

# %%
img = cv2.imread("streetsign1.jpg", 1)
plt.imshow(img[...,::-1], cmap="gray")

ss1_text = pytesseract.image_to_string(img)
print(ss1_text)

# %% [markdown]
# There are multiple issues:
#
# * text is not aligned. It is either rotated within the plane or into the plane.
#
# * Large variation in Text size
# * Background clutter
#
# Lets try a cropped region of text from the above image:

# %%
# !wget https://www.dropbox.com/s/pbfcc02azekx4kq/streetsign1_crop1.jpg?dl=0 -O ss1_crop1.jpg --quiet

# %%
img_cropped = cv2.imread("ss1_crop1.jpg", 1)
plt.imshow(img_cropped[...,::-1], cmap="gray")

ss1_text = pytesseract.image_to_string(img_cropped)
print(ss1_text)

# %%
config = ('--psm 6')
ss1_crop1_text = pytesseract.image_to_string(img_cropped,config=config)
print(ss1_crop1_text)
# Out:
# ab)
# -— ae | aN

# %% [markdown]
# Try alligning the image horizontally:

# %%
# !wget https://www.dropbox.com/s/2y0mhmfnyvvz9tf/streetsign1_crop1_aligned.png?dl=0 -O crop1_aligned.png --quiet

# %%
img_cr_algd = cv2.imread("crop1_aligned.png", 1)
plt.imshow(img_cr_algd[...,::-1], cmap="gray")

# %%
config = ('--psm 6')
ss1_crop1_aligned_text = pytesseract.image_to_string(img_cr_algd,config=config)
print(ss1_crop1_aligned_text)
# Out:
# BROADWAY

# %% [markdown]
# #Common Pitfalls
# Even with all these tricks, it is important to keep a note of common pitfalls to avoid:
#
# * If the image contains too much variation in text size, it is difficult to recognize all the text, because if you want to recognize small text (by increasing the image size) , then the bigger text will suffer and vice-versa. So, it is important to focus on what information you want to extract.
#
# * It is not wise to always convert to grayscale image for natural images.
#
# * Whatever processing you think of, it is advisable to check on a few images in your dataset before deploying it to production as the algorithm might not be as robust as you expect it to be.
